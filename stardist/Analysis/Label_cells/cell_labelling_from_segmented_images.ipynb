# %%
from cell_labelling_functions import *

# %%
######### INPUTS ###########
# List of WSI paths
WSI_paths = [
    r'\\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic'
    ]
# date = '12_27_2024' # date of the segmentation
date = '1_1_2025' # date of the segmentation
saveMASKS =0 # save segmented cells masks
target_resolution=1 # mask resolution 1->10x
RGBfeatures=1 # do you want to extract rgb features from contours 1-yes,0-no
gj=1 # do the geojson countours of the segmented cells, 1 if yes, 0 if no
inverse=0

# Change this to the model you want to load
model_name = "panin_healthy"  #"pdac" "panin" "panin_healthy"  "monkey"  "fallopian_tube"  

############################
for WSI_path in WSI_paths:
    # Define output paths
    out_pth = os.path.join(WSI_path, f'StarDist_{date}_{model_name}')
    out_pth_json = os.path.join(out_pth, 'json')
    out_pth_tif = os.path.join(out_pth, 'stardist_masks')
    output_pixres = os.path.join(WSI_path,'segmentation_analysis', 'pix_res_info')
    outpthpkl = os.path.join(out_pth, 'stardist_feature_df_pickles_classes')
    outpthmat=os.path.join(outpthpkl,'mat')
    out_pth_contours = os.path.join(out_pth_json, 'geojsons', '32_polys_20x')
    out_pth_analysis = os.path.join(out_pth, 'analysis')
    
    # Create directories if they don't exist
    for path in [out_pth, out_pth_json, out_pth_tif,output_pixres,outpthpkl,outpthmat,out_pth_contours,out_pth_analysis]:
        os.makedirs(path, exist_ok=True)
    
    print(out_pth_json)
# Out:
# \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json

# %%
out_pth_analysis_stats = os.path.join(out_pth_analysis, 'stats')
out_pth_analysis_boxplots = os.path.join(out_pth_analysis, 'boxplots')
out_pth_analysis_histograms = os.path.join(out_pth_analysis, 'histograms')
out_pth_analysis_scatterplots = os.path.join(out_pth_analysis, 'scatterplots')
out_pth_analysis_violin = os.path.join(out_pth_analysis, 'violinplots')
out_pth_analysis_densitycurves = os.path.join(out_pth_analysis, 'density_curves')
out_pth_analysis_heatmap = os.path.join(out_pth_analysis, 'heatmap')
    
# Create directories if they don't exist
for path in [out_pth_analysis_stats,out_pth_analysis_boxplots,out_pth_analysis_histograms,
             out_pth_analysis_scatterplots,out_pth_analysis_violin,out_pth_analysis_densitycurves,out_pth_analysis_heatmap]:
    os.makedirs(path, exist_ok=True)

# %%
out_pth_analysis_violin
# Out:
# '\\\\169.254.138.20\\Andre\\data\\Stardist\\Healthy nPOD\\nondiabetic\\StarDist_1_1_2025_panin_healthy\\analysis\\violinplots'

# %%
# path 10x H&E stained images
pth10x=r'\\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\10x'
# pth10x=r'\\10.162.80.16\Andre_expansion\data\PanNET AK\10x'

# path to the 10x segmented images
pth10xsegmented=os.path.join(pth10x, 'classification_12152024_HE')
# pth10xsegmented=os.path.join(pth10x, 'classification_01_25_2024_10x_PNET')

# Class names and colors
class_names = ["islets of Langerhans", "pancreatic ducts", "blood vessels", "fat",
               "acini", "stroma", "background", "nerves"]
class_colors = [
    [70, 220, 220], [80, 70, 220], [70, 180, 80], [220, 220, 80],
    [130, 50, 190], [240, 180, 230], [255, 255, 255], [160, 130, 40]
]
# class_names = ["islets_of_Langerhans", "normal_epithelium", "smooth_muscle", "fat", "acini", "stroma", "nontissue", "PanIN", "nerves", "immune_hotspots", "endothelium", "PanNET"]
# class_colors=[
#      [70,220,220],  # 1 islet
#      [80,70,220],  # 2 duct
#      [70,180,80],  # 3 smooth muscle
#      [220,220,80],  # 4 fat
#      [130,50,190],  # % 5 acinus
#      [240,180,230],  # 6 connective tissue
#      [255,255,255],  # 7 whitespace
#      [210,80,75 ],  # 8 PanIN
#      [160,130,40],  # 9 nerves
#      [50,50,50],  # 10 immune
#      [160,30,120],  # 11 endothelium
#      [15,80,110]   # 12 PanNET
# ]
class_colors_norm = [[c / 255 for c in color] for color in class_colors]

# pixel resolution of the segmented images from first matfile .mat in output_pixres
pthmatfiles = get_sorted_files(output_pixres, '.mat')
mat = loadmat(pthmatfiles[0])
res = mat['pix_res'][0]  # Extract the 'pix_res' array

# Extract resolution values from the nested structure
pixelres = float(res[0][0][0])

pthjsonfiles = get_sorted_files(out_pth_json, '.json')
WSIs = get_sorted_files(WSI_path, '.svs','.ndpi')
dfs = get_sorted_files(outpthpkl, '.pkl')

# %%
# make geojson contours of the segmented cells with respective classes
make_geojson_contours_with_classes(
    out_pth_json= out_pth_json,
    ds_amt=1,
    ds_mask=1/pixelres, # 1/0.4416->10x usually;
    class_names=class_names,
    class_colors=class_colors_norm,
    pth10xsegmented=pth10xsegmented
)
# Out:
# 1 / 101
# 6516-001_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-001_HE.geojson
# 2 / 101
# 6516-005_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-005_HE.geojson
# 3 / 101
# 6516-009_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-009_HE.geojson
# 4 / 101
# 6516-013_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-013_HE.geojson
# 5 / 101
# 6516-017_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-017_HE.geojson
# 6 / 101
# 6516-021_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-021_HE.geojson
# 7 / 101
# 6516-025_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-025_HE.geojson
# 8 / 101
# 6516-029_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-029_HE.geojson
# 9 / 101
# 6516-033_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-033_HE.geojson
# 10 / 101
# 6516-037_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-037_HE.geojson
# 11 / 101
# 6516-041_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-041_HE.geojson
# 12 / 101
# 6516-045_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-045_HE.geojson
# 13 / 101
# 6516-049_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-049_HE.geojson
# 14 / 101
# 6516-053_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-053_HE.geojson
# 15 / 101
# 6516-057_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-057_HE.geojson
# 16 / 101
# 6516-061_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-061_HE.geojson
# 17 / 101
# 6516-065_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-065_HE.geojson
# 18 / 101
# 6516-069_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-069_HE.geojson
# 19 / 101
# 6516-073_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-073_HE.geojson
# 20 / 101
# 6516-077_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-077_HE.geojson
# 21 / 101
# 6516-081_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-081_HE.geojson
# 22 / 101
# 6516-085_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-085_HE.geojson
# 23 / 101
# 6516-089_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-089_HE.geojson
# 24 / 101
# 6516-093_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-093_HE.geojson
# 25 / 101
# 6516-097_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-097_HE.geojson
# 26 / 101
# 6516-101_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-101_HE.geojson
# 27 / 101
# 6516-105_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-105_HE.geojson
# 28 / 101
# 6516-109_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-109_HE.geojson
# 29 / 101
# 6516-113_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-113_HE.geojson
# 30 / 101
# 6516-117_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-117_HE.geojson
# 31 / 101
# 6516-121_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-121_HE.geojson
# 32 / 101
# 6516-125_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-125_HE.geojson
# 33 / 101
# 6516-129_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-129_HE.geojson
# 34 / 101
# 6516-133_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-133_HE.geojson
# 35 / 101
# 6516-137_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-137_HE.geojson
# 36 / 101
# 6516-141_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-141_HE.geojson
# 37 / 101
# 6516-145_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-145_HE.geojson
# 38 / 101
# 6516-149_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-149_HE.geojson
# 39 / 101
# 6516-153_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-153_HE.geojson
# 40 / 101
# 6516-157_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-157_HE.geojson
# 41 / 101
# 6516-161_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-161_HE.geojson
# 42 / 101
# 6516-165_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-165_HE.geojson
# 43 / 101
# 6516-169_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-169_HE.geojson
# 44 / 101
# 6516-173_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-173_HE.geojson
# 45 / 101
# 6516-177_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-177_HE.geojson
# 46 / 101
# 6516-181_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-181_HE.geojson
# 47 / 101
# 6516-185_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-185_HE.geojson
# 48 / 101
# 6516-189_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-189_HE.geojson
# 49 / 101
# 6516-193_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-193_HE.geojson
# 50 / 101
# 6516-197_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-197_HE.geojson
# 51 / 101
# 6516-201_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-201_HE.geojson
# 52 / 101
# 6516-205_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-205_HE.geojson
# 53 / 101
# 6516-209_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-209_HE.geojson
# 54 / 101
# 6516-213_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-213_HE.geojson
# 55 / 101
# 6516-217_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-217_HE.geojson
# 56 / 101
# 6516-221_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-221_HE.geojson
# 57 / 101
# 6516-225_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-225_HE.geojson
# 58 / 101
# 6516-229_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-229_HE.geojson
# 59 / 101
# 6516-233_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-233_HE.geojson
# 60 / 101
# 6516-237_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-237_HE.geojson
# 61 / 101
# 6516-241_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-241_HE.geojson
# 62 / 101
# 6516-245_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-245_HE.geojson
# 63 / 101
# 6516-249_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-249_HE.geojson
# 64 / 101
# 6516-253_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-253_HE.geojson
# 65 / 101
# 6516-257_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-257_HE.geojson
# 66 / 101
# 6516-261_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-261_HE.geojson
# 67 / 101
# 6516-265_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-265_HE.geojson
# 68 / 101
# 6516-269_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-269_HE.geojson
# 69 / 101
# 6516-273_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-273_HE.geojson
# 70 / 101
# 6516-277_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-277_HE.geojson
# 71 / 101
# 6516-281_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-281_HE.geojson
# 72 / 101
# 6516-285_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-285_HE.geojson
# 73 / 101
# 6516-289_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-289_HE.geojson
# 74 / 101
# 6516-293_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-293_HE.geojson
# 75 / 101
# 6516-297_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-297_HE.geojson
# 76 / 101
# 6516-301_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-301_HE.geojson
# 77 / 101
# 6516-305_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-305_HE.geojson
# 78 / 101
# 6516-309_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-309_HE.geojson
# 79 / 101
# 6516-313_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-313_HE.geojson
# 80 / 101
# 6516-317_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-317_HE.geojson
# 81 / 101
# 6516-321_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-321_HE.geojson
# 82 / 101
# 6516-325_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-325_HE.geojson
# 83 / 101
# 6516-329_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-329_HE.geojson
# 84 / 101
# 6516-333_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-333_HE.geojson
# 85 / 101
# 6516-337_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-337_HE.geojson
# 86 / 101
# 6516-341_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-341_HE.geojson
# 87 / 101
# 6516-345_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-345_HE.geojson
# 88 / 101
# 6516-349_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-349_HE.geojson
# 89 / 101
# 6516-353_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-353_HE.geojson
# 90 / 101
# 6516-357_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-357_HE.geojson
# 91 / 101
# 6516-361_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-361_HE.geojson
# 92 / 101
# 6516-365_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-365_HE.geojson
# 93 / 101
# 6516-369_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-369_HE.geojson
# 94 / 101
# 6516-373_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-373_HE.geojson
# 95 / 101
# 6516-377_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-377_HE.geojson
# 96 / 101
# 6516-381_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-381_HE.geojson
# 97 / 101
# 6516-385_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-385_HE.geojson
# 98 / 101
# 6516-389_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-389_HE.geojson
# 99 / 101
# 6516-393_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-393_HE.geojson
# 100 / 101
# 6516-397_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-397_HE.geojson
# 101 / 101
# 6516-401_HE.json
# Skipping \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\json\geojsons\32_polys_20x_labels\6516-401_HE.geojson

# %%
# EXTRACTS FEATURES FROM JSON CONTOURS AND SAVES THEM IN A PICKLE DATAFRAME
# computes also the RGB average intensities inside of each contour 
make_RGBfeatures_df_pkl_from_contours_jsons_with_classes(pthjsonfiles, WSIs, outpthpkl, segmented_image_dir=pth10xsegmented, ds_mask=1/pixelres,class_names=class_names)
# Out:
# PanNET 1  1/6
# Loading segmented image: \\10.162.80.16\Andre_expansion\data\PanNET AK\10x\classification_01_25_2024_10x_PNET\PanNET 1.tif
# using tifffile to open large tiff
# centroid passed: [20, 3520]
# centroid passed: [138, 10]
# centroid passed: [116, 4]
# centroid passed: [4, 3628]
# centroid passed: [580, 14]
# centroid passed: [12, 3650]
# centroid passed: [8, 3496]
# centroid passed: [28, 24328]
# centroid passed: [28, 24338]
# centroid passed: [18, 41930]
# centroid passed: [26, 77692]
# centroid passed: [16, 95784]
# centroid passed: [12, 95796]
# centroid passed: [8366, 97912]
# centroid passed: [8362, 97898]
# centroid passed: [28820, 12]
# centroid passed: [31322, 4]
# centroid passed: [46286, 97902]
# centroid passed: [46288, 97914]
# centroid passed: [51982, 14]
# centroid passed: [52032, 10]
# centroid passed: [52984, 28168]
# centroid passed: [52978, 78278]
# centroid passed: [52978, 78244]
# centroid passed: [52972, 77904]
# centroid passed: [52984, 78150]
# centroid passed: [52976, 78188]
# centroid passed: [52964, 78222]
# centroid passed: [52984, 83886]
# PanNET 2  2/6
# Loading segmented image: \\10.162.80.16\Andre_expansion\data\PanNET AK\10x\classification_01_25_2024_10x_PNET\PanNET 2.tif
# centroid passed: [1150, 78710]
# PanNET 3  3/6
# Loading segmented image: \\10.162.80.16\Andre_expansion\data\PanNET AK\10x\classification_01_25_2024_10x_PNET\PanNET 3.tif
# centroid passed: [41228, 51818]
# centroid passed: [50670, 1890]
# centroid passed: [50680, 16186]
# centroid passed: [50660, 23294]
# PanNET 4  4/6
# Loading segmented image: \\10.162.80.16\Andre_expansion\data\PanNET AK\10x\classification_01_25_2024_10x_PNET\PanNET 4.tif
# centroid passed: [29816, 8]
# centroid passed: [36622, 12]
# centroid passed: [36602, 6]
# centroid passed: [36616, 4]
# centroid passed: [36582, 18]
# centroid passed: [43356, 10]
# centroid passed: [40274, 4]
# centroid passed: [44494, 6]
# centroid passed: [44394, 12]
# centroid passed: [44504, 16]
# centroid passed: [44486, 12]
# centroid passed: [44524, 20]
# centroid passed: [47226, 4688]
# PanNET 5  5/6
# Loading segmented image: \\10.162.80.16\Andre_expansion\data\PanNET AK\10x\classification_01_25_2024_10x_PNET\PanNET 5.tif
# centroid passed: [50660, 17944]
# centroid passed: [50668, 28736]
# PanNET 6  6/6
# Loading segmented image: \\10.162.80.16\Andre_expansion\data\PanNET AK\10x\classification_01_25_2024_10x_PNET\PanNET 6.tif
# centroid passed: [16, 18602]
# centroid passed: [24, 33396]

# %%
# MAKE LIST OF FEATURES DF PKL FILES AND SAVES THEM AS MAT FILES 
featuresdf_pkl2mat(outpthpkl, outpthmat, dfs)
# Out:
# saving here: \\10.162.80.16\Andre_expansion\data\PanNET AK\StarDist_2_8_2025_panin_healthy\stardist_feature_df_pickles_classes\mat
# Saving mat file PanNET 1  1/6
# Saving mat file PanNET 2  2/6
# Saving mat file PanNET 3  3/6
# Saving mat file PanNET 4  4/6
# Saving mat file PanNET 5  5/6
# Saving mat file PanNET 6  6/6

# %% [markdown]
# ## Load pkl dataframe with all cell features

# %%
sns.set(style="ticks")
# Convert RGB colors to HEX
class_colors_hex = rgb_to_hex(class_colors)
# Create a palette dictionary mapping class names to HEX colors
palette = dict(zip(class_names, class_colors_hex))
# Class Mapping: Integer labels to Class Names
class_mapping = {
    1: "islets of Langerhans",
    2: "pancreatic ducts",
    3: "blood vessels",
    4: "fat",
    5: "acini",
    6: "stroma",
    7: "background",
    8: "nerves"
}

# %%
# Load and combine data
df = load_data(outpthpkl)
# Out:
# Loading 101 .pkl files: 100%|██████████| 101/101 [00:26<00:00,  3.76file/s]
# Combined DataFrame shape: (77472414, 24)

# %%
np.shape(df)
# Out:
# (77472414, 24)

# %%
df.head()
# Out:
#    Centroid_x  Centroid_y        Area  Perimeter  Circularity  Aspect Ratio  \
# 0        3846        3940   69.212999  32.629459     0.816917      1.068202
# 1        3938        3370   82.077680  34.490782     0.867019      1.090769
# 2        3694        3706   64.027091  31.317665     0.820342      1.195362
# 3        3480        3220  142.771116  43.364521     0.954072      1.003961
# 4        2862        3818   92.614019  36.009363     0.897544      1.160240
#
#    compactness  eccentricity    extent  form_factor  ...  major_axis_length  \
# 0    15.382683      0.351595  0.763635     1.224115  ...           9.839606
# 1    14.493758      0.399383  0.769058     1.153377  ...          10.789451
# 2    15.318455      0.547865  0.764372     1.219004  ...          10.006434
# 3    13.171303      0.088740  0.772137     1.048139  ...          13.624839
# 4    14.000842      0.507095  0.769274     1.114152  ...          11.818761
#
#    orientation_degrees  r_mean_intensity  g_mean_intensity  b_mean_intensity  \
# 0           310.451468            123.94             73.74            114.99
# 1           110.076865            121.86             75.37            113.99
# 2          8271.605190            128.60             75.30            117.62
# 3          5249.915076            128.72             87.49            124.16
# 4           714.128899            111.87             62.14            104.20
#
#        r_std      g_std      b_std  slide_num  class_name
# 0  19.152527  11.525329  17.727196        001           5
# 1  20.453880  12.892477  19.025358        001           5
# 2  18.981965  11.382687  17.314053        001           5
# 3  27.853750  19.622668  26.802380        001           5
# 4  19.963185  11.340197  18.524890        001           5
#
# [5 rows x 24 columns]

# %%
# Define numerical features to analyze (exclude 'slide_num' and 'class_name')
numerical_features = [col for col in df.columns if col not in ['slide_num', 'class_name', 'Centroid_x', 'Centroid_y']]

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

def calculate_statistics(df, feature, class_mapping):
    """
    Calculate statistics (mean, median, std, etc.) for a given feature across classes.

    Parameters:
        df (pd.DataFrame): DataFrame containing the data with 'class_name' and the feature.
        feature (str): The feature to calculate statistics for.
        class_mapping (dict): Mapping from class integers to class names.

    Returns:
        pd.DataFrame: A DataFrame containing statistics for each class.
    """
    # Exclude class 7 ("background")
    filtered_df = df[df['class_name'] != 7].copy()

    # Map class integers to class names
    filtered_df['class_name_str'] = filtered_df['class_name'].map(class_mapping)

    # Drop any rows where mapping resulted in NaN (i.e., classes not in class_mapping)
    filtered_df = filtered_df.dropna(subset=['class_name_str'])

    # Group by class and calculate statistics
    stats_df = filtered_df.groupby('class_name_str')[feature].agg(
        mean=np.mean,
        median=np.median,
        std=np.std,
        min=np.min,
        max=np.max,
        count='count'
    ).reset_index()

    return stats_df

def plot_violin_shifted(df, feature, class_mapping, palette, output_dir):
    """
    Create a violin plot for a given feature across classes, excluding class 7,
    sorted by median descending. Plot data points shifted to the right of violins.

    Parameters:
        df (pd.DataFrame): DataFrame containing the data with 'class_name' and the feature.
        feature (str): The feature to plot.
        class_mapping (dict): Mapping from class integers to class names.
        palette (dict): Mapping from class names to colors.
        output_dir (str): Path to save the plot and statistics CSV.
    """
    # Define the resolution for pixel-to-micron conversion (0.504 microns/pixel)
    resolution = 0.504  # microns per pixel

    # Ensure the output directory exists
    os.makedirs(output_dir, exist_ok=True)

    # 1. Exclude class 7 ("background")
    filtered_df = df[df['class_name'] != 7].copy()

    if filtered_df.empty:
        print("No data available after excluding Class 7 ('background').")
        return

    # 2. Map class integers to class names
    filtered_df['class_name_str'] = filtered_df['class_name'].map(class_mapping)

    # Drop any rows where mapping resulted in NaN (i.e., classes not in class_mapping)
    filtered_df = filtered_df.dropna(subset=['class_name_str'])

    # 3. Convert pixel-based metrics to microns
    if feature in ['Area', 'Perimeter', 'maximum_radius', 'mean_radius', 'median_radius',
                   'minor_axis_length', 'major_axis_length']:
        # Apply pixel-to-micron conversion
        if feature == 'Area':
            filtered_df[feature] = filtered_df[feature] * (resolution ** 2)  # Area scales with resolution squared
        else:
            filtered_df[feature] = filtered_df[feature] * resolution  # Linear metrics scale with resolution

    # 4. Calculate median per class and sort classes descending
    median_per_class = filtered_df.groupby('class_name_str')[feature].median().sort_values(ascending=False)
    sorted_classes = median_per_class.index.tolist()

    # 5. Set the order for the plot
    sns.set(style="ticks")
    plt.figure(figsize=(12, 8))

    # 6. Create violin plot
    ax = sns.violinplot(
        x='class_name_str',
        y=feature,
        data=filtered_df,
        order=sorted_classes,
        palette=palette,
        inner='quartile',
        width=0.35,
        linewidth=2.5
    )

    # 7. Shift data points to the right
    shift = 0.5  # Amount to shift data points to the right
    for i, class_name in enumerate(sorted_classes):
        subset = filtered_df[filtered_df['class_name_str'] == class_name]
        # Generate jittered x positions shifted to the right
        x = np.random.normal(loc=i, scale=0.05, size=len(subset)) + shift
        scatter_color = palette.get(class_name, 'black')
        plt.scatter(x, subset[feature], color=scatter_color, s=0.5, alpha=0.3)

    # 8. Apply despine for a clean look
    sns.despine()

    # 9. Rotate x labels for better readability
    plt.xticks(rotation=45, fontsize=18)
    plt.yticks(fontsize=18)

    # 10. Set titles and labels
    plt.title(f'Violin Plot of {feature} by Class', fontsize=20)
    plt.xlabel('Class Name', fontsize=20)
    plt.ylabel(f'{feature} ({ "µm²" if feature == "Area" else "µm" })', fontsize=20)  # Add units

    # 11. Adjust layout for better spacing
    plt.tight_layout()

    # 12. Save the plot as PNG
    plot_path = os.path.join(output_dir, f'violin_{feature}.png')
    plt.savefig(plot_path, dpi=300)
    plt.close()
    print(f"Violin plot saved to {plot_path}")

# %%
df.columns
# Out:
# Index(['Centroid_x', 'Centroid_y', 'Area', 'Perimeter', 'Circularity',
#        'Aspect Ratio', 'compactness', 'eccentricity', 'extent', 'form_factor',
#        'maximum_radius', 'mean_radius', 'median_radius', 'minor_axis_length',
#        'major_axis_length', 'orientation_degrees', 'r_mean_intensity',
#        'g_mean_intensity', 'b_mean_intensity', 'r_std', 'g_std', 'b_std',
#        'slide_num', 'class_name'],
#       dtype='object')

# %%
numerical_features
# Out:
# ['Area',
#  'Perimeter',
#  'maximum_radius',
#  'mean_radius',
#  'median_radius',
#  'minor_axis_length',
#  'major_axis_length']

# %%
# Define the directory containing the CSV files
csv_directory = out_pth_analysis_violin # Update this path to your directory

# Define the features to plot
sns.set(style="ticks")
# plt.style.use("custom.mplstyle")
resolution = 0.504  # microns per pixel

# Create a figure for plotting
plt.figure(figsize=(15, 5))

# Ensure the output directory for SVG files exists
output_svg_dir = os.path.join(csv_directory, 'svg_plots')
os.makedirs(output_svg_dir, exist_ok=True)

# Loop through each feature and plot the mean ± std
for feature in numerical_features:
    # Load the CSV file
    csv_path = os.path.join(csv_directory, f'stats_{feature}.csv')
    if not os.path.exists(csv_path):
        print(f"CSV file for {feature} not found at {csv_path}. Skipping.")
        continue

    # Read the CSV file
    stats_df = pd.read_csv(csv_path)

    # Convert pixel-based metrics to microns
    if feature in ['Area', 'Perimeter', 'maximum_radius', 'mean_radius', 'median_radius',
                   'minor_axis_length', 'major_axis_length']:
        # Convert mean and std to microns
        stats_df['mean'] = stats_df['mean'] * (resolution ** 2 if feature == 'Area' else resolution)
        stats_df['std'] = stats_df['std'] * (resolution ** 2 if feature == 'Area' else resolution)

    # Sort the DataFrame by mean value (highest to lowest)
    stats_df = stats_df.sort_values(by='mean', ascending=False)

    # Create a new figure for each feature
    plt.figure(figsize=(10, 6))

    # Plot the mean values with error bars (std) and use colors from the palette
    for _, row in stats_df.iterrows():
        class_name = row['class_name_str']
        plt.errorbar(
            class_name,  # x-axis: class name
            row['mean'],  # y-axis: mean value
            yerr=row['std'],  # error bars: standard deviation
            fmt='o',  # marker style
            capsize=18,  # error bar cap size
            linestyle='none',  # no connecting lines
            markersize=18,  # marker size
            color=palette.get(class_name, 'black'),  # use color from palette
            label=f'{class_name}'
        )

    # Add labels and title
    plt.xlabel('Class Name', fontsize=18)
    plt.ylabel(f'{feature} ({ "µm²" if feature == "Area" else "µm" })', fontsize=18)
    plt.title(f'Mean {feature} with Standard Deviation', fontsize=14)
    plt.xticks(rotation=60, fontsize=18)  # Rotate x-axis labels for readability

    # Remove top and right spines (box off)
    sns.despine()

    # Make the bottom and left axis lines thicker
    for spine in plt.gca().spines.values():
        spine.set_linewidth(2)  # Set the linewidth to 2 (or any desired thickness)

    # Make the ticks thicker (same thickness as axis lines)
    plt.tick_params(axis='both', which='both', width=2)  # Set tick thickness to 2

    # Make the y-axis tick labels larger
    plt.tick_params(axis='y', labelsize=18)  # Set y-axis tick label font size to 14

    # Add a legend
    plt.legend(fontsize=18, bbox_to_anchor=(1.05, 1), loc='upper left')

    # Adjust layout
    plt.tight_layout()

    # Save the plot as an SVG file
    svg_path = os.path.join(output_svg_dir, f'mean_{feature}_with_std.svg')
    plt.savefig(svg_path, format='svg', dpi=500)
    plt.close()
    print(f"Plot saved to {svg_path}")
# Out:
# Plot saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\svg_plots\mean_Area_with_std.svg
# Plot saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\svg_plots\mean_Perimeter_with_std.svg
# Plot saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\svg_plots\mean_Circularity_with_std.svg
# Plot saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\svg_plots\mean_Aspect Ratio_with_std.svg
# Plot saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\svg_plots\mean_compactness_with_std.svg
# Plot saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\svg_plots\mean_eccentricity_with_std.svg
# Plot saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\svg_plots\mean_extent_with_std.svg
# Plot saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\svg_plots\mean_form_factor_with_std.svg
# Plot saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\svg_plots\mean_maximum_radius_with_std.svg
# Plot saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\svg_plots\mean_mean_radius_with_std.svg
# Plot saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\svg_plots\mean_median_radius_with_std.svg
# Plot saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\svg_plots\mean_minor_axis_length_with_std.svg
# Plot saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\svg_plots\mean_major_axis_length_with_std.svg
# Plot saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\svg_plots\mean_orientation_degrees_with_std.svg
# Plot saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\svg_plots\mean_r_mean_intensity_with_std.svg
# Plot saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\svg_plots\mean_g_mean_intensity_with_std.svg
# Plot saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\svg_plots\mean_b_mean_intensity_with_std.svg
# Plot saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\svg_plots\mean_r_std_with_std.svg
# Plot saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\svg_plots\mean_g_std_with_std.svg
# Plot saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\svg_plots\mean_b_std_with_std.svg

# %% [markdown]
# ##NEW CODES

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

def calculate_statistics(df, feature, class_mapping):
    """
    Calculate statistics (mean, median, std, etc.) for a given feature across classes.
    Also computes the coefficient of variation (CV = std/mean).

    Parameters:
        df (pd.DataFrame): DataFrame containing the data with 'class_name' and the feature.
        feature (str): The feature to calculate statistics for.
        class_mapping (dict): Mapping from class integers to class names.

    Returns:
        pd.DataFrame: A DataFrame containing statistics for each class.
    """
    # Exclude class 7 ("background") and map class names
    filtered_df = df[df['class_name'] != 7].copy()
    filtered_df['class_name_str'] = filtered_df['class_name'].map(class_mapping)
    filtered_df = filtered_df.dropna(subset=['class_name_str'])

    # Group by class and calculate statistics
    stats_df = filtered_df.groupby('class_name_str')[feature].agg(
        mean=np.mean,
        median=np.median,
        std=np.std,
        min=np.min,
        max=np.max,
        count='count'
    ).reset_index()

    # Calculate coefficient of variation (CV = std/mean), avoiding division by zero
    stats_df['coef_var'] = stats_df.apply(lambda row: row['std'] / row['mean'] if row['mean'] != 0 else np.nan, axis=1)

    return stats_df

def plot_violin_shifted(df, feature, class_mapping, palette, output_dir):
    """
    Create a violin plot for a given feature across classes (excluding class 7) sorted by median descending.
    Also computes and saves statistics—including coefficient of variation—to CSV and Excel files.

    Parameters:
        df (pd.DataFrame): DataFrame with 'class_name' and the feature.
        feature (str): The feature to plot.
        class_mapping (dict): Mapping from class integers to class names.
        palette (dict): Mapping from class names to colors.
        output_dir (str): Directory to save the plot and statistics files.
    """
    resolution = 0.504  # microns per pixel
    os.makedirs(output_dir, exist_ok=True)

    # Filter and map class names
    filtered_df = df[df['class_name'] != 7].copy()
    filtered_df['class_name_str'] = filtered_df['class_name'].map(class_mapping)
    filtered_df = filtered_df.dropna(subset=['class_name_str'])

    # Convert pixel-based metrics to microns if applicable
    pixel_features = ['Area', 'Perimeter', 'maximum_radius', 'mean_radius',
                      'median_radius', 'minor_axis_length', 'major_axis_length']
    if feature in pixel_features:
        if feature == 'Area':
            filtered_df[feature] = filtered_df[feature] * (resolution ** 2)
        else:
            filtered_df[feature] = filtered_df[feature] * resolution

    # Calculate statistics and convert them if needed
    stats_df = calculate_statistics(df, feature, class_mapping)
    if feature in pixel_features:
        factor = resolution ** 2 if feature == 'Area' else resolution
        stats_df['mean']   = stats_df['mean'] * factor
        stats_df['std']    = stats_df['std'] * factor
        stats_df['median'] = stats_df['median'] * factor
        stats_df['min']    = stats_df['min'] * factor
        stats_df['max']    = stats_df['max'] * factor
        # Note: coef_var remains the same because it is a ratio

    # Save statistics to CSV and Excel (CV is included)
    stats_csv_path = os.path.join(output_dir, f'stats_{feature}.csv')
    stats_df.to_csv(stats_csv_path, index=False)
    print(f"Statistics saved to {stats_csv_path}")

    stats_excel_path = os.path.join(output_dir, f'stats_{feature}.xlsx')
    stats_df.to_excel(stats_excel_path, index=False)
    print(f"Statistics saved to {stats_excel_path}")

    # Sort classes by median descending for plotting
    median_per_class = filtered_df.groupby('class_name_str')[feature].median().sort_values(ascending=False)
    sorted_classes = median_per_class.index.tolist()

    sns.set(style="ticks")
    plt.figure(figsize=(12, 8))

    # Create violin plot
    ax = sns.violinplot(
        x='class_name_str',
        y=feature,
        data=filtered_df,
        order=sorted_classes,
        palette=palette,
        inner='quartile',
        width=0.35,
        linewidth=2.5
    )

    # Plot shifted data points
    shift = 0.5
    for i, class_name in enumerate(sorted_classes):
        subset = filtered_df[filtered_df['class_name_str'] == class_name]
        x = np.random.normal(loc=i, scale=0.05, size=len(subset)) + shift
        scatter_color = palette.get(class_name, 'black')
        plt.scatter(x, subset[feature], color=scatter_color, s=0.5, alpha=0.3)

    sns.despine()
    plt.xticks(rotation=45, fontsize=18)
    plt.yticks(fontsize=18)
    plt.title(f'Violin Plot of {feature} by Class', fontsize=20)
    plt.xlabel('Class Name', fontsize=20)
    plt.ylabel(f'{feature} ({"µm²" if feature=="Area" else "µm"})', fontsize=20)
    plt.tight_layout()

    plot_path = os.path.join(output_dir, f'violin_{feature}.png')
    plt.savefig(plot_path, dpi=300)
    plt.close()
    print(f"Violin plot saved to {plot_path}")

# %%
def plot_violin_shifted(df, feature, class_mapping, palette, output_dir, plot=1):
    """
    Create a violin plot for a given feature across classes (excluding class 7) sorted by median descending.
    Also computes and saves statistics—including coefficient of variation—to CSV and Excel files.

    Parameters:
        df (pd.DataFrame): DataFrame with 'class_name' and the feature.
        feature (str): The feature to plot.
        class_mapping (dict): Mapping from class integers to class names.
        palette (dict): Mapping from class names to colors.
        output_dir (str): Directory to save the plot and statistics files.
        plot (int): 1 to plot and save the violin plot; 0 to skip plotting.
    """
    resolution = 0.504  # microns per pixel
    os.makedirs(output_dir, exist_ok=True)

    # Filter and map class names
    filtered_df = df[df['class_name'] != 7].copy()
    filtered_df['class_name_str'] = filtered_df['class_name'].map(class_mapping)
    filtered_df = filtered_df.dropna(subset=['class_name_str'])

    # Convert pixel-based metrics to microns if applicable
    pixel_features = ['Area', 'Perimeter', 'maximum_radius', 'mean_radius',
                      'median_radius', 'minor_axis_length', 'major_axis_length']
    if feature in pixel_features:
        if feature == 'Area':
            filtered_df[feature] = filtered_df[feature] * (resolution ** 2)
        else:
            filtered_df[feature] = filtered_df[feature] * resolution

    # Calculate statistics and convert them if needed
    stats_df = calculate_statistics(df, feature, class_mapping)
    if feature in pixel_features:
        factor = resolution ** 2 if feature == 'Area' else resolution
        stats_df['mean']   = stats_df['mean'] * factor
        stats_df['std']    = stats_df['std'] * factor
        stats_df['median'] = stats_df['median'] * factor
        stats_df['min']    = stats_df['min'] * factor
        stats_df['max']    = stats_df['max'] * factor
        # Note: coef_var remains the same because it is a ratio

    # Save statistics to CSV and Excel (CV is included)
    stats_csv_path = os.path.join(output_dir, f'stats_{feature}.csv')
    stats_df.to_csv(stats_csv_path, index=False)
    print(f"Statistics saved to {stats_csv_path}")

    stats_excel_path = os.path.join(output_dir, f'stats_{feature}.xlsx')
    stats_df.to_excel(stats_excel_path, index=False)
    print(f"Statistics saved to {stats_excel_path}")

    # If plotting is requested, create and save the violin plot
    if plot:
        # Sort classes by median descending for plotting
        median_per_class = filtered_df.groupby('class_name_str')[feature].median().sort_values(ascending=False)
        sorted_classes = median_per_class.index.tolist()

        sns.set(style="ticks")
        plt.figure(figsize=(12, 8))

        # Create violin plot
        ax = sns.violinplot(
            x='class_name_str',
            y=feature,
            data=filtered_df,
            order=sorted_classes,
            palette=palette,
            inner='quartile',
            width=0.35,
            linewidth=2.5
        )

        # Plot shifted data points
        shift = 0.5
        for i, class_name in enumerate(sorted_classes):
            subset = filtered_df[filtered_df['class_name_str'] == class_name]
            x = np.random.normal(loc=i, scale=0.05, size=len(subset)) + shift
            scatter_color = palette.get(class_name, 'black')
            plt.scatter(x, subset[feature], color=scatter_color, s=0.5, alpha=0.3)

        sns.despine()
        plt.xticks(rotation=45, fontsize=18)
        plt.yticks(fontsize=18)
        plt.title(f'Violin Plot of {feature} by Class', fontsize=20)
        plt.xlabel('Class Name', fontsize=20)
        plt.ylabel(f'{feature} ({"µm²" if feature=="Area" else "µm"})', fontsize=20)
        plt.tight_layout()

        plot_path = os.path.join(output_dir, f'violin_{feature}.png')
        plt.savefig(plot_path, dpi=300)
        plt.close()
        print(f"Violin plot saved to {plot_path}")
    else:
        print("Plotting skipped..")

# %%
# plot_violin_shifted(df, numerical_features, class_mapping, palette, out_pth_analysis_violin)
# Iterate over numerical features and plot
for feature in numerical_features:
    # plot_violin_shifted(df, feature, class_mapping, palette, out_pth_analysis_violin,plot=1)
    plot_violin_shifted(df, feature, class_mapping, palette, out_pth_analysis_violin,plot=0)
# Out:
# 3639545555.py (26): The provided callable <function mean at 0x00000249D21608B0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
# 3639545555.py (26): The provided callable <function median at 0x00000249D229ECA0> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
# 3639545555.py (26): The provided callable <function std at 0x00000249D2160A60> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
# 3639545555.py (26): The provided callable <function amin at 0x00000249D215CE50> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
# 3639545555.py (26): The provided callable <function amax at 0x00000249D215CCA0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
# Statistics saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\stats_Area.csv
# Statistics saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\stats_Area.xlsx
# Plotting skipped (plot=0).
# 3639545555.py (26): The provided callable <function mean at 0x00000249D21608B0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
# 3639545555.py (26): The provided callable <function median at 0x00000249D229ECA0> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
# 3639545555.py (26): The provided callable <function std at 0x00000249D2160A60> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
# 3639545555.py (26): The provided callable <function amin at 0x00000249D215CE50> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
# 3639545555.py (26): The provided callable <function amax at 0x00000249D215CCA0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
# Statistics saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\stats_Perimeter.csv
# Statistics saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\stats_Perimeter.xlsx
# Plotting skipped (plot=0).
# 3639545555.py (26): The provided callable <function mean at 0x00000249D21608B0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
# 3639545555.py (26): The provided callable <function median at 0x00000249D229ECA0> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
# 3639545555.py (26): The provided callable <function std at 0x00000249D2160A60> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
# 3639545555.py (26): The provided callable <function amin at 0x00000249D215CE50> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
# 3639545555.py (26): The provided callable <function amax at 0x00000249D215CCA0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
# Statistics saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\stats_Circularity.csv
# Statistics saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\stats_Circularity.xlsx
# Plotting skipped (plot=0).
# 3639545555.py (26): The provided callable <function mean at 0x00000249D21608B0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
# 3639545555.py (26): The provided callable <function median at 0x00000249D229ECA0> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
# 3639545555.py (26): The provided callable <function std at 0x00000249D2160A60> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
# 3639545555.py (26): The provided callable <function amin at 0x00000249D215CE50> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
# 3639545555.py (26): The provided callable <function amax at 0x00000249D215CCA0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
# Statistics saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\stats_Aspect Ratio.csv
# Statistics saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\stats_Aspect Ratio.xlsx
# Plotting skipped (plot=0).
# 3639545555.py (26): The provided callable <function mean at 0x00000249D21608B0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
# 3639545555.py (26): The provided callable <function median at 0x00000249D229ECA0> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
# 3639545555.py (26): The provided callable <function std at 0x00000249D2160A60> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
# 3639545555.py (26): The provided callable <function amin at 0x00000249D215CE50> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
# 3639545555.py (26): The provided callable <function amax at 0x00000249D215CCA0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
# Statistics saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\stats_compactness.csv
# Statistics saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\stats_compactness.xlsx
# Plotting skipped (plot=0).
# 3639545555.py (26): The provided callable <function mean at 0x00000249D21608B0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
# 3639545555.py (26): The provided callable <function median at 0x00000249D229ECA0> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
# 3639545555.py (26): The provided callable <function std at 0x00000249D2160A60> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
# 3639545555.py (26): The provided callable <function amin at 0x00000249D215CE50> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
# 3639545555.py (26): The provided callable <function amax at 0x00000249D215CCA0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
# Statistics saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\stats_eccentricity.csv
# Statistics saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\stats_eccentricity.xlsx
# Plotting skipped (plot=0).
# 3639545555.py (26): The provided callable <function mean at 0x00000249D21608B0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
# 3639545555.py (26): The provided callable <function median at 0x00000249D229ECA0> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
# 3639545555.py (26): The provided callable <function std at 0x00000249D2160A60> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
# 3639545555.py (26): The provided callable <function amin at 0x00000249D215CE50> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
# 3639545555.py (26): The provided callable <function amax at 0x00000249D215CCA0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
# Statistics saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\stats_extent.csv
# Statistics saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\stats_extent.xlsx
# Plotting skipped (plot=0).
# 3639545555.py (26): The provided callable <function mean at 0x00000249D21608B0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
# 3639545555.py (26): The provided callable <function median at 0x00000249D229ECA0> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
# 3639545555.py (26): The provided callable <function std at 0x00000249D2160A60> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
# 3639545555.py (26): The provided callable <function amin at 0x00000249D215CE50> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
# 3639545555.py (26): The provided callable <function amax at 0x00000249D215CCA0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
# Statistics saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\stats_form_factor.csv
# Statistics saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\stats_form_factor.xlsx
# Plotting skipped (plot=0).
# 3639545555.py (26): The provided callable <function mean at 0x00000249D21608B0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
# 3639545555.py (26): The provided callable <function median at 0x00000249D229ECA0> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
# 3639545555.py (26): The provided callable <function std at 0x00000249D2160A60> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
# 3639545555.py (26): The provided callable <function amin at 0x00000249D215CE50> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
# 3639545555.py (26): The provided callable <function amax at 0x00000249D215CCA0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
# Statistics saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\stats_maximum_radius.csv
# Statistics saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\stats_maximum_radius.xlsx
# Plotting skipped (plot=0).
# 3639545555.py (26): The provided callable <function mean at 0x00000249D21608B0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
# 3639545555.py (26): The provided callable <function median at 0x00000249D229ECA0> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
# 3639545555.py (26): The provided callable <function std at 0x00000249D2160A60> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
# 3639545555.py (26): The provided callable <function amin at 0x00000249D215CE50> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
# 3639545555.py (26): The provided callable <function amax at 0x00000249D215CCA0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
# Statistics saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\stats_mean_radius.csv
# Statistics saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\stats_mean_radius.xlsx
# Plotting skipped (plot=0).
# 3639545555.py (26): The provided callable <function mean at 0x00000249D21608B0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
# 3639545555.py (26): The provided callable <function median at 0x00000249D229ECA0> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
# 3639545555.py (26): The provided callable <function std at 0x00000249D2160A60> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
# 3639545555.py (26): The provided callable <function amin at 0x00000249D215CE50> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
# 3639545555.py (26): The provided callable <function amax at 0x00000249D215CCA0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
# Statistics saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\stats_median_radius.csv
# Statistics saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\stats_median_radius.xlsx
# Plotting skipped (plot=0).
# 3639545555.py (26): The provided callable <function mean at 0x00000249D21608B0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
# 3639545555.py (26): The provided callable <function median at 0x00000249D229ECA0> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
# 3639545555.py (26): The provided callable <function std at 0x00000249D2160A60> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
# 3639545555.py (26): The provided callable <function amin at 0x00000249D215CE50> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
# 3639545555.py (26): The provided callable <function amax at 0x00000249D215CCA0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
# Statistics saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\stats_minor_axis_length.csv
# Statistics saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\stats_minor_axis_length.xlsx
# Plotting skipped (plot=0).
# 3639545555.py (26): The provided callable <function mean at 0x00000249D21608B0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
# 3639545555.py (26): The provided callable <function median at 0x00000249D229ECA0> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
# 3639545555.py (26): The provided callable <function std at 0x00000249D2160A60> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
# 3639545555.py (26): The provided callable <function amin at 0x00000249D215CE50> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
# 3639545555.py (26): The provided callable <function amax at 0x00000249D215CCA0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
# Statistics saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\stats_major_axis_length.csv
# Statistics saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\stats_major_axis_length.xlsx
# Plotting skipped (plot=0).
# 3639545555.py (26): The provided callable <function mean at 0x00000249D21608B0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
# 3639545555.py (26): The provided callable <function median at 0x00000249D229ECA0> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
# 3639545555.py (26): The provided callable <function std at 0x00000249D2160A60> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
# 3639545555.py (26): The provided callable <function amin at 0x00000249D215CE50> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
# 3639545555.py (26): The provided callable <function amax at 0x00000249D215CCA0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
# Statistics saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\stats_orientation_degrees.csv
# Statistics saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\stats_orientation_degrees.xlsx
# Plotting skipped (plot=0).
# 3639545555.py (26): The provided callable <function mean at 0x00000249D21608B0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
# 3639545555.py (26): The provided callable <function median at 0x00000249D229ECA0> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
# 3639545555.py (26): The provided callable <function std at 0x00000249D2160A60> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
# 3639545555.py (26): The provided callable <function amin at 0x00000249D215CE50> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
# 3639545555.py (26): The provided callable <function amax at 0x00000249D215CCA0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
# Statistics saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\stats_r_mean_intensity.csv
# Statistics saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\stats_r_mean_intensity.xlsx
# Plotting skipped (plot=0).
# 3639545555.py (26): The provided callable <function mean at 0x00000249D21608B0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
# 3639545555.py (26): The provided callable <function median at 0x00000249D229ECA0> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
# 3639545555.py (26): The provided callable <function std at 0x00000249D2160A60> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
# 3639545555.py (26): The provided callable <function amin at 0x00000249D215CE50> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
# 3639545555.py (26): The provided callable <function amax at 0x00000249D215CCA0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
# Statistics saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\stats_g_mean_intensity.csv
# Statistics saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\stats_g_mean_intensity.xlsx
# Plotting skipped (plot=0).
# 3639545555.py (26): The provided callable <function mean at 0x00000249D21608B0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
# 3639545555.py (26): The provided callable <function median at 0x00000249D229ECA0> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
# 3639545555.py (26): The provided callable <function std at 0x00000249D2160A60> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
# 3639545555.py (26): The provided callable <function amin at 0x00000249D215CE50> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
# 3639545555.py (26): The provided callable <function amax at 0x00000249D215CCA0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
# Statistics saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\stats_b_mean_intensity.csv
# Statistics saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\stats_b_mean_intensity.xlsx
# Plotting skipped (plot=0).
# 3639545555.py (26): The provided callable <function mean at 0x00000249D21608B0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
# 3639545555.py (26): The provided callable <function median at 0x00000249D229ECA0> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
# 3639545555.py (26): The provided callable <function std at 0x00000249D2160A60> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
# 3639545555.py (26): The provided callable <function amin at 0x00000249D215CE50> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
# 3639545555.py (26): The provided callable <function amax at 0x00000249D215CCA0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
# Statistics saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\stats_r_std.csv
# Statistics saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\stats_r_std.xlsx
# Plotting skipped (plot=0).
# 3639545555.py (26): The provided callable <function mean at 0x00000249D21608B0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
# 3639545555.py (26): The provided callable <function median at 0x00000249D229ECA0> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
# 3639545555.py (26): The provided callable <function std at 0x00000249D2160A60> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
# 3639545555.py (26): The provided callable <function amin at 0x00000249D215CE50> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
# 3639545555.py (26): The provided callable <function amax at 0x00000249D215CCA0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
# Statistics saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\stats_g_std.csv
# Statistics saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\stats_g_std.xlsx
# Plotting skipped (plot=0).
# 3639545555.py (26): The provided callable <function mean at 0x00000249D21608B0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
# 3639545555.py (26): The provided callable <function median at 0x00000249D229ECA0> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
# 3639545555.py (26): The provided callable <function std at 0x00000249D2160A60> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
# 3639545555.py (26): The provided callable <function amin at 0x00000249D215CE50> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
# 3639545555.py (26): The provided callable <function amax at 0x00000249D215CCA0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
# Statistics saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\stats_b_std.csv
# Statistics saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\stats_b_std.xlsx
# Plotting skipped (plot=0).

# %%
# -------------------------------
# Plotting mean ± std and coefficient of variation from saved statistics
# -------------------------------

# Define the directory containing the CSV/Excel files (update this path accordingly)
csv_directory = out_pth_analysis_violin  # Update this path to your directory

# Define numerical features and the palette (update as needed)
numerical_features = ['Area', 'Perimeter', 'maximum_radius', 'mean_radius',
                      'median_radius', 'minor_axis_length', 'major_axis_length']

# Ensure the output directory for SVG plots exists
output_svg_dir = os.path.join(csv_directory, 'svg_plots')
os.makedirs(output_svg_dir, exist_ok=True)

for feature in numerical_features:
    csv_path = os.path.join(csv_directory, f'stats_{feature}.csv')
    if not os.path.exists(csv_path):
        print(f"CSV file for {feature} not found at {csv_path}. Skipping.")
        continue

    # Read the saved statistics (which include the coefficient of variation)
    stats_df = pd.read_csv(csv_path)

    # Plot Mean ± Standard Deviation
    plt.figure(figsize=(10, 6))
    for _, row in stats_df.iterrows():
        class_name = row['class_name_str']
        plt.errorbar(
            class_name,            # x-axis: class name
            row['mean'],           # y-axis: mean value
            yerr=row['std'],       # error bars: standard deviation
            fmt='o',               # marker style
            capsize=18,            # error bar cap size
            linestyle='none',      # no connecting lines
            markersize=18,         # marker size
            color=palette.get(class_name, 'black'),
            label=f'{class_name}'
        )
    plt.xlabel('Class Name', fontsize=18)
    plt.ylabel(f'{feature} ({"µm²" if feature=="Area" else "µm"})', fontsize=18)
    plt.title(f'Mean {feature} with Standard Deviation', fontsize=14)
    plt.xticks(rotation=60, fontsize=18)
    sns.despine()
    for spine in plt.gca().spines.values():
        spine.set_linewidth(2)
    plt.tick_params(axis='both', which='both', width=2)
    plt.tick_params(axis='y', labelsize=18)
    plt.legend(fontsize=18, bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    svg_path = os.path.join(output_svg_dir, f'mean_{feature}_with_std.svg')
    plt.savefig(svg_path, format='svg', dpi=500)
    plt.close()
    print(f"Mean ± Std plot saved to {svg_path}")

    # Plot Coefficient of Variation (CV)
    plt.figure(figsize=(10, 6))
    for _, row in stats_df.iterrows():
        class_name = row['class_name_str']
        plt.scatter(
            class_name,
            row['coef_var'],
            color=palette.get(class_name, 'black'),
            s=100,
            label=f'{class_name}'
        )
    plt.xlabel('Class Name', fontsize=18)
    plt.ylabel('Coefficient of Variation', fontsize=18)
    plt.title(f'Coefficient of Variation of {feature}', fontsize=14)
    plt.xticks(rotation=60, fontsize=18)
    sns.despine()
    plt.legend(fontsize=18, bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    cv_svg_path = os.path.join(output_svg_dir, f'cv_{feature}.svg')
    plt.savefig(cv_svg_path, format='svg', dpi=500)
    plt.close()
    print(f"Coefficient of Variation plot saved to {cv_svg_path}")
# Out:
# Mean ± Std plot saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\svg_plots\mean_Area_with_std.svg
# Coefficient of Variation plot saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\svg_plots\cv_Area.svg
# Mean ± Std plot saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\svg_plots\mean_Perimeter_with_std.svg
# Coefficient of Variation plot saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\svg_plots\cv_Perimeter.svg
# Mean ± Std plot saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\svg_plots\mean_maximum_radius_with_std.svg
# Coefficient of Variation plot saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\svg_plots\cv_maximum_radius.svg
# Mean ± Std plot saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\svg_plots\mean_mean_radius_with_std.svg
# Coefficient of Variation plot saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\svg_plots\cv_mean_radius.svg
# Mean ± Std plot saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\svg_plots\mean_median_radius_with_std.svg
# Coefficient of Variation plot saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\svg_plots\cv_median_radius.svg
# Mean ± Std plot saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\svg_plots\mean_minor_axis_length_with_std.svg
# Coefficient of Variation plot saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\svg_plots\cv_minor_axis_length.svg
# Mean ± Std plot saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\svg_plots\mean_major_axis_length_with_std.svg
# Coefficient of Variation plot saved to \\169.254.138.20\Andre\data\Stardist\Healthy nPOD\nondiabetic\StarDist_1_1_2025_panin_healthy\analysis\violinplots\svg_plots\cv_major_axis_length.svg
