# %% [markdown]
# # TRAIN

# %%
conda create --name coda_convnext python=3.10.19
conda activate coda_convnext
pip install torch==2.5.1 torchvision==0.20.1 torchaudio==2.5.1 --index-url https://download.pytorch.org/whl/cu121
pip install accelerate==1.12.0 aiohttp==3.13.3 datasets==4.6.0 evaluate==0.4.6 huggingface_hub==1.4.1 ijson==3.5.0 matplotlib==3.10.8 numpy==1.26.4 openslide-bin==4.0.0.11 openslide-python==1.4.3 pandas==2.3.3 pillow==11.3.0 PyYAML==6.0.3 safetensors==0.7.0 scikit-image==0.25.2 scikit-learn==1.7.2 scipy==1.15.3 shapely==2.1.2 tifffile==2025.5.10 timm==1.0.25 tqdm==4.67.3 transformers==5.2.0
# Out:
# Running cells with 'coda_convnext (Python 3.10.19)' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'conda install -n coda_convnext ipykernel --update-deps --force-reinstall'

# %%
# !python train_convnext_T224.py

# %% [markdown]
# # INFERENCE

# %% [markdown]
# !python predict_convnext_T224.py ^
#   --ndpi "\\kittyserverdw\Andre_kit\data\students\Diogo\data\fetal\GS40\monkey_fetus_40_0545.ndpi" ^
#   --geojson "\\kittyserverdw\Andre_kit\data\students\Diogo\data\fetal\GS40\StarDist_12_25_23_monkey\json\geojson\monkey_fetus_40_0545.geojson" ^
#   --ckpt "\\kittyserverdw\Andre_kit\data\students\Diogo\data\fetal\GS40\cellvit_training\data_for_cellvit_GS40_balanced\convnext_runs\run_fold0_convnext_large\best" ^
#   --label_space "\\kittyserverdw\Andre_kit\data\students\Diogo\data\fetal\GS40\cellvit_training\data_for_cellvit_GS40_balanced\label_map.yaml" ^
#   --out_dir "\\kittyserverdw\Andre_kit\data\students\Diogo\data\fetal\GS40\predictions_convnext\monkey_fetus_40_0545_T" ^
#   --patch 256 ^
#   --batch 64 ^
#   --chunk 100000

# %%
python fast_classify.py ^
    --ndpi "\\kittyserverdw\Andre_kit\data\students\Diogo\data\fetal\GS40\monkey_fetus_40_0545.ndpi" ^
    --geojson "\\kittyserverdw\Andre_kit\data\students\Diogo\data\fetal\GS40\StarDist_12_25_23_monkey\json\geojson\monkey_fetus_40_0545.geojson" ^
    --ckpt "\\kittyserverdw\Andre_kit\data\students\Diogo\data\fetal\GS40\cellvit_training\data_for_cellvit_GS40_balanced\convnext_runs\run_fold0_convnext_large\best" ^
    --out "\\kittyserverdw\Andre_kit\data\students\Diogo\data\fetal\GS40\predictions_convnext\monkey_fetus_40_0545_T\monkey_fetus_40_0545.geojson" ^
    --batch 128 ^
    --workers 8

# %%
python fast_classify.py ^
    --ndpi "\\kittyserverdw\Andre_kit\data\students\Diogo\data\fetal\GS40\monkey_fetus_40_0545.ndpi" ^
    --geojson "\\kittyserverdw\Andre_kit\data\students\Diogo\data\fetal\GS40\StarDist_12_25_23_monkey\json\geojson\monkey_fetus_40_0545.geojson" ^
    --ckpt "\\kittyserverdw\Andre_kit\data\students\Diogo\data\fetal\GS40\cellvit_training\data_for_cellvit_GS40_balanced\convnext_runs\run_fold0_convnext_large\best" ^
    --out "\\kittyserverdw\Andre_kit\data\students\Diogo\data\fetal\GS40\predictions_convnext\monkey_fetus_40_0545_T\monkey_fetus_40_0545.geojson" ^
    --batch 256 ^
    --workers 12

# %%
python fast_classifyv2.py ^
    --ndpi "\\kittyserverdw\Andre_kit\data\students\Diogo\data\fetal\GS40\monkey_fetus_40_0545.ndpi" ^
    --geojson "\\kittyserverdw\Andre_kit\data\students\Diogo\data\fetal\GS40\StarDist_12_25_23_monkey\json\geojson\monkey_fetus_40_0545.geojson" ^
    --ckpt "\\kittyserverdw\Andre_kit\data\students\Diogo\data\fetal\GS40\cellvit_training\data_for_cellvit_GS40_balanced\convnext_runs\run_fold0_convnext_large\best" ^
    --out "\\kittyserverdw\Andre_kit\data\students\Diogo\data\fetal\GS40\predictions_convnext\monkey_fetus_40_0545_T\monkey_fetus_40_0545.geojson" ^
    --patch_size 256 ^
    --batch 128 ^
    --tile_size 2048 ^
    --precision 1
